# %% [markdown]
# # Import Libraries

# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# # Load csv file

# %%
pd.read_csv(r'anime.csv')
# Out:
#     Rank                                              Title  Score
# 0      1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10
# 1      2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07
# 2      3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06
# 3      4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06
# 4      5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05
# 5      6  Gintama'TV (51 eps)Apr 2011 - Mar 2012534,105 ...   9.04
# 6      7  Gintama: The FinalMovie (1 eps)Jan 2021 - Jan ...   9.04
# 7      8  Hunter x Hunter (2011)TV (148 eps)Oct 2011 - S...   9.04
# 8      9  Kaguya-sama wa Kokurasetai: Ultra RomanticTV (...   9.04
# 9     10  Gintama': EnchousenTV (13 eps)Oct 2012 - Mar 2...   9.03
# 10    11  Shingeki no Kyojin: The Final Season - Kankets...   9.03
# 11    12  Ginga Eiyuu DensetsuOVA (110 eps)Jan 1988 - Ma...   9.02
# 12    13  Bleach: Sennen Kessen-hen - Ketsubetsu-tanTV (...   8.99
# ...

# %%
anime = pd.read_csv(r'anime.csv')

# %% [markdown]
# # First Five Rows From Dataset:

# %%
anime.head()
# Out:
#    Rank                                              Title  Score
# 0     1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10
# 1     2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07
# 2     3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06
# 3     4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06
# 4     5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05

# %%
# Taget a specific Row
anime.loc[2]
# Out:
# Rank                                                     3
# Title    Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...
# Score                                                 9.06
# Name: 2, dtype: object

# %% [markdown]
# ## Make a new column for episode count

# %%
anime.loc[2]['Title']
# Out:
# 'Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 - Dec 2022474,138 members'

# %%
# Extract episode count from the Title column
def extract_episodes(title):
    start = title.rfind("(")
    end = title.rfind(" eps)")
    
    if start != -1 and end != -1:
        return title[start + 1:end]
    
    return None

# %%
# Create Episodes column using the extraction function
anime["Episodes"] = anime["Title"].apply(extract_episodes)

# %%
# Check extracted episode values
anime[["Title", "Episodes"]].head(10)
# Out:
#                                                Title Episodes
# 0  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...       64
# 1  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...       24
# 2  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...       13
# 3  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...       51
# 4  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...       10
# 5  Gintama'TV (51 eps)Apr 2011 - Mar 2012534,105 ...       51
# 6  Gintama: The FinalMovie (1 eps)Jan 2021 - Jan ...        1
# 7  Hunter x Hunter (2011)TV (148 eps)Oct 2011 - S...      148
# 8  Kaguya-sama wa Kokurasetai: Ultra RomanticTV (...       13
# 9  Gintama': EnchousenTV (13 eps)Oct 2012 - Mar 2...       13

# %%
anime['Episodes'] = anime['Episodes'].str.replace("eps", "")

# %%
# Verify the problematic anime title
anime.loc[
    anime["Title"].str.contains("Hunter x Hunter", na=False),
    ["Title", "Episodes"]
]
# Out:
#                                                Title Episodes
# 7  Hunter x Hunter (2011)TV (148 eps)Oct 2011 - S...      148

# %%
# Convert Episodes column from text to integer
anime["Episodes"] = anime["Episodes"].astype(int)

# %%
anime
# Out:
#     Rank                                              Title  Score  Episodes
# 0      1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10        64
# 1      2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07        24
# 2      3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06        13
# 3      4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06        51
# 4      5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05        10
# 5      6  Gintama'TV (51 eps)Apr 2011 - Mar 2012534,105 ...   9.04        51
# 6      7  Gintama: The FinalMovie (1 eps)Jan 2021 - Jan ...   9.04         1
# 7      8  Hunter x Hunter (2011)TV (148 eps)Oct 2011 - S...   9.04       148
# 8      9  Kaguya-sama wa Kokurasetai: Ultra RomanticTV (...   9.04        13
# 9     10  Gintama': EnchousenTV (13 eps)Oct 2012 - Mar 2...   9.03        13
# 10    11  Shingeki no Kyojin: The Final Season - Kankets...   9.03         2
# ...

# %% [markdown]
# # Data Type

# %%
# Check type of Whole Column Episodes
type(anime['Episodes'])
# Out:
# pandas.core.series.Series

# %%
# Check type of Column Episodes at row 7
type(anime.loc[7]['Episodes'])
# Out:
# numpy.int64

# %% [markdown]
# # Make a new column for time span

# %%
anime.loc[7]['Title']
# Out:
# 'Hunter x Hunter (2011)TV (148 eps)Oct 2011 - Sep 20142,701,154 members'

# %%
anime = anime.drop(7, axis = 0)

# %%
anime = anime.drop(12, axis = 0)

# %%
anime = anime.drop(10, axis = 0)

# %%
anime = anime.drop(30, axis = 0)

# %%
anime
# Out:
#     Rank                                              Title  Score  Episodes
# 0      1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10        64
# 1      2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07        24
# 2      3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06        13
# 3      4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06        51
# 4      5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05        10
# 5      6  Gintama'TV (51 eps)Apr 2011 - Mar 2012534,105 ...   9.04        51
# 6      7  Gintama: The FinalMovie (1 eps)Jan 2021 - Jan ...   9.04         1
# 8      9  Kaguya-sama wa Kokurasetai: Ultra RomanticTV (...   9.04        13
# 9     10  Gintama': EnchousenTV (13 eps)Oct 2012 - Mar 2...   9.03        13
# 11    12  Ginga Eiyuu DensetsuOVA (110 eps)Jan 1988 - Ma...   9.02       110
# 13    14  Fruits Basket: The FinalTV (13 eps)Apr 2021 - ...   8.99        13
# ...

# %%
def extract_time(txt):
    check = False
    data = ""
    for i in range(len(txt)):
        if txt[i] == ')':
            for j in range(i+1, i+20):
                data += txt[j]
            return data

# %%
anime['Title'].apply(extract_time)
# Out:
# 0     Apr 2009 - Jul 2010
# 1     Apr 2011 - Sep 2011
# 2     Oct 2022 - Dec 2022
# 3     Apr 2015 - Mar 2016
# 4     Apr 2019 - Jul 2019
# 5     Apr 2011 - Mar 2012
# 6     Jan 2021 - Jan 2021
# 8     Apr 2022 - Jun 2022
# 9     Oct 2012 - Mar 2013
# 11    Jan 1988 - Mar 1997
# 13    Apr 2021 - Jun 2021
# 14    Jan 2017 - Mar 2017
# 15    Apr 2006 - Mar 2010
# 16    Sep 2016 - Sep 2016
# 17    Oct 2017 - Mar 2018
# 18    Oct 2008 - Mar 2009
# 19    Apr 2008 - Sep 2008
# 20    Jul 2013 - Jul 2013
# 21    Sep 2020 - Sep 2020
# 22    Aug 2017 - Aug 2017
# 23    Jul 2018 - Oct 2018
# 24    Apr 2004 - Sep 2005
# 25    Aug 2016 - Aug 2016
# 26    Dec 2022 - Dec 2022
# 27    Oct 2022 - Dec 2022
# 28    Dec 2022 - Dec 2022
# 29    Jan 2023 - Jun 2023
# 31    Jan 2018 - Mar 2018
# 32    Apr 2020 - Oct 2021
# 33    Jan 2019 - Apr 2019
# 34    Dec 2020 - Mar 2021
# 35    Dec 2021 - Feb 2022
# 36    Jan 2017 - Jan 2017
# 37    Apr 2023 - Jun 2023
# 38    Oct 2016 - Dec 2016
# ...

# %%
anime['Time Span'] = anime['Title'].apply(extract_time)

# %%
type(anime.loc[4]['Time Span'])
# Out:
# str

# %%
anime
# Out:
#     Rank                                              Title  Score  Episodes  \
# 0      1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10        64
# 1      2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07        24
# 2      3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06        13
# 3      4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06        51
# 4      5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05        10
# 5      6  Gintama'TV (51 eps)Apr 2011 - Mar 2012534,105 ...   9.04        51
# 6      7  Gintama: The FinalMovie (1 eps)Jan 2021 - Jan ...   9.04         1
# 8      9  Kaguya-sama wa Kokurasetai: Ultra RomanticTV (...   9.04        13
# 9     10  Gintama': EnchousenTV (13 eps)Oct 2012 - Mar 2...   9.03        13
# 11    12  Ginga Eiyuu DensetsuOVA (110 eps)Jan 1988 - Ma...   9.02       110
# 13    14  Fruits Basket: The FinalTV (13 eps)Apr 2021 - ...   8.99        13
# ...

# %%
from dateutil.relativedelta import relativedelta
from datetime import datetime

def calculate_total_months(period):
    try:
        start_str, end_str = period.split(' - ')
        start_date = datetime.strptime(start_str, '%b %Y')
        end_date = datetime.strptime(end_str, '%b %Y')
        r = relativedelta(end_date, start_date)
        return r.years * 12 + r.months + 1  # +1 to include the starting month
    except:
        return None

anime['Months'] = anime['Time Span'].apply(calculate_total_months)

# %%
anime
# Out:
#     Rank                                              Title  Score  Episodes  \
# 0      1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10        64
# 1      2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07        24
# 2      3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06        13
# 3      4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06        51
# 4      5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05        10
# 5      6  Gintama'TV (51 eps)Apr 2011 - Mar 2012534,105 ...   9.04        51
# 6      7  Gintama: The FinalMovie (1 eps)Jan 2021 - Jan ...   9.04         1
# 8      9  Kaguya-sama wa Kokurasetai: Ultra RomanticTV (...   9.04        13
# 9     10  Gintama': EnchousenTV (13 eps)Oct 2012 - Mar 2...   9.03        13
# 11    12  Ginga Eiyuu DensetsuOVA (110 eps)Jan 1988 - Ma...   9.02       110
# 13    14  Fruits Basket: The FinalTV (13 eps)Apr 2021 - ...   8.99        13
# ...

# %%
#which anime has the highest score
anime['Score'].max()
# Out:
# np.float64(9.1)

# %%
anime.loc[anime['Score'].idxmax()]
# Out:
# Rank                                                         1
# Title        Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...
# Score                                                      9.1
# Episodes                                                    64
# Time Span                                  Apr 2009 - Jul 2010
# Months                                                      16
# Name: 0, dtype: object

# %%
anime.loc[anime['Score'].idxmax()]["Title"]
# Out:
# 'Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr 2009 - Jul 20103,218,472 membersManga StoreVolume 1€4.58Preview'

# %%
#give me top 5 highest scoring anime
anime.nlargest(5, 'Score')[['Score', 'Title']]
# Out:
#    Score                                              Title
# 0   9.10  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...
# 1   9.07  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...
# 2   9.06  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...
# 3   9.06  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...
# 4   9.05  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...

# %%
anime['Title'].head()
# Out:
# 0    Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...
# 1    Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...
# 2    Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...
# 3    Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...
# 4    Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...
# Name: Title, dtype: object

# %%
#which anime has the highest episode count
anime.loc[anime['Episodes'].idxmax()]
# Out:
# Rank                                                        16
# Title        GintamaTV (201 eps)Apr 2006 - Mar 20101,034,41...
# Score                                                     8.94
# Episodes                                                   201
# Time Span                                  Apr 2006 - Mar 2010
# Months                                                      48
# Name: 15, dtype: object

# %%
#animes with top 5 episode count
anime.nlargest(5, 'Episodes')[['Episodes', 'Title']]
# Out:
#     Episodes                                              Title
# 15       201  GintamaTV (201 eps)Apr 2006 - Mar 20101,034,41...
# 11       110  Ginga Eiyuu DensetsuOVA (110 eps)Jan 1988 - Ma...
# 42        75  Hajime no IppoTV (75 eps)Oct 2000 - Mar 200255...
# 24        74  MonsterTV (74 eps)Apr 2004 - Sep 20051,041,081...
# 0         64  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...

# %%
#which is the longest running anime
anime.loc[anime['Months'].idxmax()]
# Out:
# Rank                                                        12
# Title        Ginga Eiyuu DensetsuOVA (110 eps)Jan 1988 - Ma...
# Score                                                     9.02
# Episodes                                                   110
# Time Span                                  Jan 1988 - Mar 1997
# Months                                                     111
# Name: 11, dtype: object

# %%
type(anime.loc[4]['Months'])
# Out:
# numpy.int64
